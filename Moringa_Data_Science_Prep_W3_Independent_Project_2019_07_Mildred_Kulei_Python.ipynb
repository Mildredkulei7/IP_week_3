# %% [markdown]
# <a href="https://colab.research.google.com/github/Mildredkulei7/IP_week_3/blob/main/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Mildred_Kulei_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PYTHON DATA ANALYSIS ASSIGNMENT**

# %% [markdown]
# **1.0 Importing the Libraries to be used**

# %%
# Let's import the pandas library
#
import pandas as pd

# as well as the Numpy library
import numpy as np

# %% [markdown]
# **1.1 Loading our Datasets**

# %%
#loading cells_geo_description excel file 
geo_d = 'cells_geo_description.xlsx'

# Then load the first sheet of the Excel file into a data frame
df_geo_d = pd.read_excel(geo_d, sheet_name=0, header=0)
df_geo_d
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
#loading cells_geo  csv file 
import pandas as pd

df = 'cells_geo.csv'
df_2 = pd.read_csv(df)
df_2
# Out:
#      ;VILLES;STATUS;LOCALISATION;DECOUPZONE;ZONENAME;LONGITUDE;LATITUDE;REGION;AREA;CELL_ID;SITE_CODE
# 0     0;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 1     1;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 2     2;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 3     3;ASSINIE;In Service;INTERIEUR;Grand-EST;"ASSI...
# 4     4;ASSINIE;In Service;INTERIEUR;Grand-EST;"ASSI...
# ...                                                 ...
# 3969  3969;ZUENOULA;In Service;INTERIEUR;Grand-NORD;...
# 3970  3970;ZUENOULA;In Service;INTERIEUR;Grand-NORD;...
# 3971  3971;ZUENOULA;In Service;INTERIEUR;Grand-NORD;...
# 3972  3972;ZUENOULA;In Service;INTERIEUR;Grand-NORD;...
# 3973  3973;ZUENOULA;In Service;INTERIEUR;Grand-NORD;...
#
# [3974 rows x 1 columns]

# %%
#loading cell_geo columns correctly
df_geo = pd.read_csv('cells_geo.csv', sep=';')
df_geo
# Out:
#       Unnamed: 0    VILLES      STATUS  ...          AREA     CELL_ID   SITE_CODE
# 0              0    ADJAME  In Service  ...           NaN  fbb2e75af3  0bb492ef17
# 1              1    ADJAME  In Service  ...           NaN  1502501d78  0bb492ef17
# 2              2    ADJAME  In Service  ...           NaN  0c2e182a0c  0bb492ef17
# 3              3   ASSINIE  In Service  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4              4   ASSINIE  In Service  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...          ...       ...         ...  ...           ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
#loading CDR_description excel file 
CDR_d = 'CDR_description.xlsx'

df_cdr = pd.read_excel(CDR_d, sheet_name=0, header=1)
df_cdr
# Out:
#            PRODUCT                                       Voice or SMS   String
# 0            VALUE                                      Billing price  Integer
# 1        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 2     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 3  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 4  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 5        COUNTRY_A                  Country of party A (useless here)   String
# 6        COUNTRY_B                  Country of party B (useless here)   String
# 7          CELL_ID                                     ID of the cell   String
# 8          SITE_ID                                     ID of the SITE   String

# %%
#loading Telcom_dataset csv file
df_tel1 = pd.read_csv('Telcom_dataset.csv')
df_tel1
# Out:
#      PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
#loading Telcom dataset 2 csv file
df_tel2 = pd.read_csv('Telcom_dataset2.csv')
df_tel2

df_tel2.head(6)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# 5     sms      0  2012-05-07 23:05:41.0  ...     19e2e  /MMplBlWjh  /MMplBlWjh
#
# [6 rows x 10 columns]

# %%
#loading Telcom dataset 3 csv file and showing first five rows
df_tel3 = pd.read_csv('Telcom_dataset3.csv')
df_tel3.head(5)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
#joining the three telcom datasets

df_telcom = pd.concat((df_tel1, df_tel2,df_tel3), axis=0)
df_telcom
# Out:
#      PRODUTC  VALUE               DATETIME  ... DW_B_NUMBER      CELLID     SIET_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...         NaN         NaN         NaN
# 1        sms      0  2012-05-06 23:05:25.0  ...         NaN         NaN         NaN
# 2        sms     25  2012-05-06 23:05:41.0  ...         NaN         NaN         NaN
# 3      Voice     56  2012-05-06 23:05:42.0  ...         NaN         NaN         NaN
# 4      Voice     14  2012-05-06 23:06:29.0  ...         NaN         NaN         NaN
# ...      ...    ...                    ...  ...         ...         ...         ...
# 4996     NaN      0                    NaN  ...         NaN  2aa04dcab7  f7d63a29e5
# 4997     NaN     62                    NaN  ...         NaN  7f1f2f889f  b4ddb9e93c
# 4998     NaN     32                    NaN  ...         NaN  a4731e780e  d68260ef50
# 4999     NaN     30                    NaN  ...         NaN  98ed726da2  b4130b54ab
# ...

# %% [markdown]
# The datasets are not merged correctly because the datasets has column name a bit different from others.

# %%
#lable encoding
df_tel1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUTC          5001 non-null   object
#  1   VALUE            5001 non-null   int64
#  2   DATETIME         5001 non-null   object
#  3   CELL_ON_SITE     5001 non-null   object
#  4   DW_A_NUMBER_INT  5001 non-null   object
#  5   DW_B_NUMBER_INT  5001 non-null   object
#  6   COUNTRY_A        5001 non-null   object
#  7   COUNTRY_B        5001 non-null   object
#  8   CELL_ID          5001 non-null   object
#  9   SITE_ID          4285 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB

# %%
df_tel2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       5001 non-null   object
#  1   VALUE         5001 non-null   int64
#  2   DATE_TIME     5001 non-null   object
#  3   CELL_ON_SITE  5001 non-null   object
#  4   DW_A_NUMBER   5001 non-null   object
#  5   DW_B_NUMBER   5001 non-null   object
#  6   COUNTRY_A     5001 non-null   object
#  7   COUNTRY_B     5001 non-null   object
#  8   CELL_ID       5001 non-null   object
#  9   SITE_ID       4325 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB

# %%
df_tel2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       5001 non-null   object
#  1   VALUE         5001 non-null   int64
#  2   DATE_TIME     5001 non-null   object
#  3   CELL_ON_SITE  5001 non-null   object
#  4   DW_A_NUMBER   5001 non-null   object
#  5   DW_B_NUMBER   5001 non-null   object
#  6   COUNTRY_A     5001 non-null   object
#  7   COUNTRY_B     5001 non-null   object
#  8   CELL_ID       5001 non-null   object
#  9   SITE_ID       4325 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB

# %%
#renaming the columns of telcom dataset 1 to march the column nae in the other two dataset, from PRODUTC TO PRODUCT
df_telcom1 = df_tel1.rename(columns = {'PRODUTC': 'PRODUCT', 'DATETIME': 'DATE_TIME','DW_A_NUMBER_INT': 'DW_A_NUMBER','DW_B_NUMBER_INT': 'DW_B_NUMBER'}, inplace = False)
df_telcom1
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
#renaming the columns of telcom dataset 3 to march the column name in the other two dataset, from PRODUTC TO PRODUCT
df_telcom3 = df_tel3.rename(columns = {'DW_A_NUMBER_INT': 'DW_A_NUMBER','DW_B_NUMBER_INT': 'DW_B_NUMBER', 'SIET_ID': 'SITE_ID', 'CELLID': 'CELL_ID'}, inplace = False)
df_telcom3
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1        sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3        sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
frames = [df_telcom1,df_tel2,df_telcom3]

df_telcom = pd.concat(frames)
df_telcom
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %% [markdown]
# **2. Which ones were the most used city for the three days?**

# %%
df_geo.VILLES.value_counts()
# Out:
# COCODY         354
# YOPOUGON       295
# ABOBO          255
# MARCORY        141
# TREICHVILLE    132
#               ...
# KRIZABAHIO       3
# KOTOULA          2
# MEMNI            2
# DANANON          1
# OUANGOLO         1
# Name: VILLES, Length: 504, dtype: int64

# %% [markdown]
# The Most used cities are; COCODY, YOPOUGON, ABOBO, MARCORY & TREICHVILLE

# %% [markdown]
# **3.Which cities were the most used during business and home hours?**

# %%
#first merging the two data sets
df_geo1 = df_geo.merge(df_telcom, how='outer', on=['CELL_ID']) 
df_geo1
# Out:
#        Unnamed: 0   VILLES      STATUS  ... COUNTRY_A COUNTRY_B     SITE_ID
# 0             0.0   ADJAME  In Service  ...       NaN       NaN         NaN
# 1             1.0   ADJAME  In Service  ...       NaN       NaN         NaN
# 2             2.0   ADJAME  In Service  ...       NaN       NaN         NaN
# 3             3.0  ASSINIE  In Service  ...       NaN       NaN         NaN
# 4             4.0  ASSINIE  In Service  ...       NaN       NaN         NaN
# ...           ...      ...         ...  ...       ...       ...         ...
# 18972         NaN      NaN         NaN  ...     19e2e     19e2e  cc45940406
# 18973         NaN      NaN         NaN  ...     19e2e     19e2e  ab91f5b21d
# 18974         NaN      NaN         NaN  ...     19e2e     19e2e  cdf82e4fe3
# 18975         NaN      NaN         NaN  ...     19e2e     19e2e  5f6100dbe1
# 18976         NaN      NaN         NaN  ...     19e2e     OTHER  8a96bae9c1
#
# [18977 rows x 21 columns]

# %%
df_geo1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18977 entries, 0 to 18976
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3974 non-null   float64
#  1   VILLES        3974 non-null   object
#  2   STATUS        3907 non-null   object
#  3   LOCALISATION  3974 non-null   object
#  4   DECOUPZONE    3974 non-null   object
#  5   ZONENAME      3968 non-null   object
#  6   LONGITUDE     3974 non-null   float64
#  7   LATITUDE      3974 non-null   float64
#  8   REGION        3974 non-null   object
#  9   AREA          3951 non-null   object
#  10  CELL_ID       18977 non-null  object
#  11  SITE_CODE     3974 non-null   object
#  12  PRODUCT       15003 non-null  object
#  13  VALUE         15003 non-null  float64
#  14  DATE_TIME     15003 non-null  object
#  15  CELL_ON_SITE  15003 non-null  object
#  16  DW_A_NUMBER   15003 non-null  object
#  17  DW_B_NUMBER   15003 non-null  object
# ...

# %%
df_telcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15003 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       15003 non-null  object
#  1   VALUE         15003 non-null  int64
#  2   DATE_TIME     15003 non-null  object
#  3   CELL_ON_SITE  15003 non-null  object
#  4   DW_A_NUMBER   15003 non-null  object
#  5   DW_B_NUMBER   15003 non-null  object
#  6   COUNTRY_A     15003 non-null  object
#  7   COUNTRY_B     15003 non-null  object
#  8   CELL_ID       15003 non-null  object
#  9   SITE_ID       13006 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# **4.Most used city for the three days?**

# %%
df_geo.VILLES.describe()
# Out:
# count       3974
# unique       504
# top       COCODY
# freq         354
# Name: VILLES, dtype: object

# %% [markdown]
# The most used city in the data for three days was COCODY.

# %%
df_telcom.PRODUCT.describe()
# Out:
# count     15003
# unique        3
# top         sms
# freq       7071
# Name: PRODUCT, dtype: object

# %%
df_telcom.PRODUCT.value_counts()
# Out:
# sms      7071
# Voice    5666
# data     2266
# Name: PRODUCT, dtype: int64

# %% [markdown]
# There are 3 available products offered by MTN telecom; that is sms,voice and data. The most used product is sms.
